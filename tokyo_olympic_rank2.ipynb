# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
import warnings
warnings.filterwarnings("ignore")
# Out:
# Setup Complete

# %%
df = pd.read_csv('Tokyo 2021 dataset.csv')

# %%
df
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode
# 0     113              1     USA
# 1      88              2     CHN
# 2      58              5     JPN
# 3      65              4     GBR
# 4      71              3     ROC
# ..    ...            ...     ...
# 88      1             77     GHA
# 89      1             77     GRN
# 90      1             77     KUW
# 91      1             77     MDA
# 92      1             77     SYR
#
# [93 rows x 8 columns]

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (16,8))
sns.regplot(x = df.Rank, y= df['Rank by Total']);

# %% [markdown]
# # Rank is determined by the Gold Medal counts (Global Scoring)

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (16,8))
ax = sns.barplot(x = df['Rank'],y = df['Gold Medal'])
ax.bar_label(ax.containers[0])
plt.title('Gold medal counts to rank')
plt.show();

# %%
df
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
#     Total  Rank by Total NOCCode
# 0     113              1     USA
# 1      88              2     CHN
# 2      58              5     JPN
# 3      65              4     GBR
# 4      71              3     ROC
# ..    ...            ...     ...
# 88      1             77     GHA
# 89      1             77     GRN
# 90      1             77     KUW
# 91      1             77     MDA
# 92      1             77     SYR
#
# [93 rows x 8 columns]

# %% [markdown]
# # Rank by Total is determined by Total Medal accumulated (US Scoring)

# %%
df_total = df.sort_values(['Rank by Total'])

# %%
sns.set_style('darkgrid')
# sns.set_context({"figure.figsize": (24, 10)})
plt.figure(figsize = (16,8))
# ax = sns.barplot(x = 'Rank by Total',y = 'Total', data = df)
ax = sns.barplot(x = 'Rank by Total',y = 'Total', data = df_total)
ax.bar_label(ax.containers[0], label_type = 'center')
ax.set_title('Relation of Rank by Total and Total Medals')
ax.set_ylabel('Total Medals')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.set_style('darkgrid')
p1 = ax.bar(df['Rank'], df['Gold Medal'], label='Gold Medal')
p2 = ax.bar(df['Rank'], df['Silver Medal'],bottom=df['Gold Medal'], label='Silver Medal')
p3 = ax.bar(df['Rank'], df['Bronze Medal'],bottom=df['Gold Medal'] + df['Silver Medal'], label='Bronze Medal')

ax.set_ylabel('Medal')
ax.set_xlabel('Rank')

ax.set_xticks(df['Rank'])
ax.legend()

ax.set_title('Rank by Medals')
# ax.bar_label(p1, label_type='center')
# ax.bar_label(p2, label_type='center')
# ax.bar_label(p3, label_type='center')
plt.show()

# %% [markdown]
# The rank is determined by this rule:
# 1. Gold Medal counts, if it is the same then
# 2. Silver Medal counts, if it is the same then
# 3. Bronze Medal counts, if it is still the same then they will have same rank

# %%
top_10 = df.iloc[:10]
top_10_total = df_total.iloc[:10]

# %%
fig, ax = plt.subplots(figsize = (6,4))
sns.set_style('darkgrid')
p1 = ax.bar(top_10['Rank'], top_10['Gold Medal'], label='Gold Medal')
p2 = ax.bar(top_10['Rank'], top_10['Silver Medal'],bottom=top_10['Gold Medal'], label='Silver Medal')
p3 = ax.bar(top_10['Rank'], top_10['Bronze Medal'],bottom=top_10['Gold Medal'] + top_10['Silver Medal'], label='Bronze Medal')

ax.set_ylabel('Medal')
ax.set_xlabel('Rank')

ax.set_xticks(top_10['Rank'])
ax.legend()

ax.set_title('Rank by Medals')
ax.bar_label(p1, label_type='center')
ax.bar_label(p2, label_type='center')
ax.bar_label(p3, label_type='center')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,10))
sns.set_style('darkgrid')
p1 = ax.bar(df['Rank by Total'], df['Gold Medal'], label='Gold Medal')
p2 = ax.bar(df['Rank by Total'], df['Silver Medal'],bottom=df['Gold Medal'], label='Silver Medal')
p3 = ax.bar(df['Rank by Total'], df['Bronze Medal'],bottom=df['Gold Medal'] + df['Silver Medal'], label='Bronze Medal')

ax.set_ylabel('Medal')
ax.set_xlabel('Rank by Total')

ax.set_xticks(df['Rank by Total'])
ax.legend()

ax.set_title('Rank by Total According to Medals')
# ax.bar_label(p1, label_type='center')
# ax.bar_label(p2, label_type='center')
# ax.bar_label(p3, label_type='center')
plt.savefig('foo.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (6,4))
sns.set_style('darkgrid')
p1 = ax.bar(top_10_total['Rank by Total'], top_10_total['Gold Medal'], label='Gold Medal')
p2 = ax.bar(top_10_total['Rank by Total'], top_10_total['Silver Medal'],bottom=top_10_total['Gold Medal'], label='Silver Medal')
p3 = ax.bar(top_10_total['Rank by Total'], top_10_total['Bronze Medal'],bottom=top_10_total['Gold Medal'] + top_10_total['Silver Medal'], label='Bronze Medal')

ax.set_ylabel('Medal')
ax.set_xlabel('Rank by Total')

ax.set_xticks(top_10_total['Rank by Total'])
ax.legend()

ax.set_title('Rank by Total According to Medals')
ax.bar_label(p1, label_type='center')
ax.bar_label(p2, label_type='center')
ax.bar_label(p3, label_type='center')
ax.bar_label(p3, labels = df['Total'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10484/3041577783.py in <module>
#      15 ax.bar_label(p2, label_type='center')
#      16 ax.bar_label(p3, label_type='center')
# ---> 17 ax.bar_label(p3, labels = df['Total'])
#      18 plt.show()
#
# c:\users\dell\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_axes.py in bar_label(self, container, labels, fmt, label_type, padding, **kwargs)
#    2626             bars, errs, datavalues, labels
#    2627         ):
# -> 2628             (x0, y0), (x1, y1) = bar.get_bbox().get_points()
#    2629             xc, yc = (x0 + x1) / 2, (y0 + y1) / 2
#    2630
#
# AttributeError: 'NoneType' object has no attribute 'get_bbox'

# %%
country = pd.read_csv('Country.csv', index_col = 0)

# %%
country
# Out:
#            Country         Income group  Rank  Gold Medal  Silver Medal  \
# 0    United States          High income     1          39            41
# 1            China  Upper middle income     2          38            32
# 2            Japan          High income     3          27            14
# 3   United Kingdom          High income     4          22            21
# 4        Australia          High income     6          17             7
# ..             ...                  ...   ...         ...           ...
# 77           Ghana  Lower middle income    86           0             0
# 78   Cote d'Ivoire  Lower middle income    86           0             0
# 79        Botswana  Upper middle income    86           0             0
# 80    Burkina Faso           Low income    86           0             0
# 81         Moldova  Upper middle income    86           0             0
#
#     Bronze Medal  Total  Rank by Total     PopTotal      Mean GNI
# 0             33    113              1   329064.917  56499.000000
# 1             18     88              2  1433783.692   7740.909091
# 2             17     58              5   126860.299  42995.000000
# 3             22     65              4    67530.161  42405.000000
# 4             22     46              6    25203.200  56050.000000
# ..           ...    ...            ...          ...           ...
# 77             1      1             77    30417.858   1829.090909
# 78             1      1             77    25716.554   1691.818182
# 79             1      1             77     2303.703   6935.454545
# 80             1      1             77    20321.383    723.636364
# 81             1      1             77     4043.258   3499.090909
#
# [81 rows x 10 columns]

# %%
country['Income group'].value_counts()
# Out:
# High income            36
# Upper middle income    29
# Lower middle income    13
# Low income              3
# Name: Income group, dtype: int64

# %%
country[country['Rank'] >= 40].groupby('Income group').size()
# Out:
# Income group
# High income            13
# Low income              2
# Lower middle income    11
# Upper middle income    20
# dtype: int64

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.swarmplot(x = 'Income group', y = 'Rank', data = country)
plt.title('Income group effect to Rank')
plt.show()

# %%
country.columns
# Out:
# Index(['Country', 'Income group', 'Rank', 'Gold Medal', 'Silver Medal',
#        'Bronze Medal', 'Total', 'Rank by Total', 'PopTotal', 'Mean GNI'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize = (12,4))
sns.regplot(x = 'PopTotal', y = 'Rank', data = country, ci=None)
plt.title('Total Population effect to Rank')
ticks = [1,10,20,30,40,50,60,70,80,90]
ax.set_yticks(ticks)
plt.show()

# %%
def popGroup(pop):
    if pop <= 50000:
        return 'Low population'
    elif 50000 < pop <= 100000:
        return 'Lower middle population'
    elif 100000 < pop <= 200000:
        return 'Upper middle population'
    else:
        return 'High Population'

# %%
country['Population Group'] = country['PopTotal'].apply(popGroup)

# %%
country.head()
# Out:
#           Country         Income group  Rank  Gold Medal  Silver Medal  \
# 0   United States          High income     1          39            41
# 1           China  Upper middle income     2          38            32
# 2           Japan          High income     3          27            14
# 3  United Kingdom          High income     4          22            21
# 4       Australia          High income     6          17             7
#
#    Bronze Medal  Total  Rank by Total     PopTotal      Mean GNI  \
# 0            33    113              1   329064.917  56499.000000
# 1            18     88              2  1433783.692   7740.909091
# 2            17     58              5   126860.299  42995.000000
# 3            22     65              4    67530.161  42405.000000
# 4            22     46              6    25203.200  56050.000000
#
#           Population Group
# 0          High Population
# 1          High Population
# 2  Upper middle population
# 3  Lower middle population
# 4           Low population

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.swarmplot(x = 'Population Group', y = 'Rank', data = country)
plt.title('Population group effect to Rank')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,9))
sns.regplot(x = 'Mean GNI', y = 'Rank', data = country)
plt.title('Total Population effect to Rank')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (20,9))
sns.regplot(x = 'Mean GNI', y = 'Rank', data = country)
plt.title('Total Population effect to Rank')
plt.show()
